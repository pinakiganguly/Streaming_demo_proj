# %%
# %sql
create or replace table hive_metastore.mytabs.weather_details_tab as select * from hive_metastore.mytabs.weather_streaming_table;

# %%
# %sql
select * from hive_metastore.mytabs.weather_details_tab;hive_metastore.mytabs.weather_details_tab
